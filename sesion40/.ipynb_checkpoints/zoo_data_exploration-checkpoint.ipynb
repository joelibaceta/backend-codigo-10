# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
zoo_df = pd.read_csv('zoo.csv')

# %%
class_df = pd.read_csv('class.csv')

# %%
class_df.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 41     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad

# %%
animal_df = zoo_df.merge(class_df, how="left", left_on="class_type", right_on="Class_Number")

# %%
animal_df.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  ...  fins  legs  tail  domestic  catsize  class_type  \
# 0        1         1  ...     0     4     0         0        1           1
# 1        1         1  ...     0     4     1         0        1           1
# 2        1         1  ...     1     0     1         0        0           4
# 3        1         1  ...     0     4     0         0        1           1
# 4        1         1  ...     0     4     1         0        1           1
#
#    Class_Number  Number_Of_Animal_Species_In_Class  Class_Type  \
# ...

# %%
animals_filtered_df = animal_df.drop(['class_type', 'Animal_Names', 'Number_Of_Animal_Species_In_Class'], axis=1)

# %%
animals_filtered_df.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    Class_Number Class_Type
# 0             1     Mammal
# ...

# %%
animals_filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   animal_name   101 non-null    object
#  1   hair          101 non-null    int64
#  2   feathers      101 non-null    int64
#  3   eggs          101 non-null    int64
#  4   milk          101 non-null    int64
#  5   airborne      101 non-null    int64
#  6   aquatic       101 non-null    int64
#  7   predator      101 non-null    int64
#  8   toothed       101 non-null    int64
#  9   backbone      101 non-null    int64
#  10  breathes      101 non-null    int64
#  11  venomous      101 non-null    int64
#  12  fins          101 non-null    int64
#  13  legs          101 non-null    int64
#  14  tail          101 non-null    int64
#  15  domestic      101 non-null    int64
#  16  catsize       101 non-null    int64
#  17  Class_Number  101 non-null    int64
# ...

# %%
animals_filtered_df.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# ...

# %%
plt.rcParams['figure.figsize'] = (7,7)

# %%
sns.countplot(x=animals_filtered_df['Class_Type'])
# Out:
# <AxesSubplot:xlabel='Class_Type', ylabel='count'>

# %%
plt.rcParams['figure.figsize'] = (16,10)

# %%
df_temp = animals_filtered_df.drop(['Class_Number'], axis=1)

# %%
df_temp = df_temp.groupby(by='animal_name').mean()

# %%
sns.heatmap(df_temp)
# Out:
# <AxesSubplot:ylabel='animal_name'>

# %%
df_temp2 = animals_filtered_df.drop(['Class_Number'], axis=1)

# %%
df_temp2 = df_temp2.groupby(by='Class_Type').mean()

# %%
sns.heatmap(df_temp2, annot=True)
# Out:
# <AxesSubplot:ylabel='Class_Type'>
